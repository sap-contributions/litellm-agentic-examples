# %% [markdown]
# # AWS Strands Agents example with LiteLLM and SAP LLMs
#
# ## [How AWS Strands Agents work](https://strandsagents.com/latest/documentation/docs/)
#
# ## Installation

# %%
! pip install strands-agents
# Out:
# Collecting strands-agents
#   Downloading strands_agents-1.15.0-py3-none-any.whl.metadata (13 kB)
# Collecting boto3<2.0.0,>=1.26.0 (from strands-agents)
#   Downloading boto3-1.40.66-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<2.0.0,>=1.29.0 (from strands-agents)
#   Downloading botocore-1.40.66-py3-none-any.whl.metadata (5.7 kB)
# Collecting docstring-parser<1.0,>=0.15 (from strands-agents)
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from strands-agents) (4.25.1)
# Collecting mcp<2.0.0,>=1.11.0 (from strands-agents)
#   Downloading mcp-1.20.0-py3-none-any.whl.metadata (85 kB)
# Collecting opentelemetry-api<2.0.0,>=1.30.0 (from strands-agents)
#   Using cached opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 (from strands-agents)
#   Using cached opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.30.0 (from strands-agents)
#   Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from strands-agents) (2.12.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from strands-agents) (4.15.0)
# Collecting watchdog<7.0.0,>=6.0.0 (from strands-agents)
#   Using cached watchdog-6.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (44 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.26.0->strands-agents)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3<2.0.0,>=1.26.0->strands-agents)
#   Using cached s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.28.0)
# Requirement already satisfied: anyio>=4.5 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (4.11.0)
# Collecting httpx-sse>=0.4 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: httpx>=0.27.1 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.28.1)
# Collecting pydantic-settings>=2.5.2 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-multipart>=0.0.9 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading sse_starlette-3.0.3-py3-none-any.whl.metadata (12 kB)
# Collecting starlette>=0.27 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting uvicorn>=0.31.1 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-instrumentation==0.59b0 (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Using cached opentelemetry_instrumentation-0.59b0-py3-none-any.whl.metadata (7.1 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Using cached wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=18.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents) (1.3.1)
# Requirement already satisfied: certifi in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents) (0.16.0)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents) (1.2.1)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents)
#   Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: six>=1.5 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents) (1.17.0)
# Requirement already satisfied: click>=7.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents) (8.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents) (2.0.0)
# Requirement already satisfied: pycparser in /Users/vasilisa/PycharmProjects/litellm-agentic-examples/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents) (2.23)
# Downloading strands_agents-1.15.0-py3-none-any.whl (249 kB)
# Downloading boto3-1.40.66-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.66-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 9.1 MB/s eta 0:00:00a 0:00:01
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading mcp-1.20.0-py3-none-any.whl (173 kB)
# Using cached opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Using cached opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl (9.3 kB)
# Using cached opentelemetry_instrumentation-0.59b0-py3-none-any.whl (33 kB)
# Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Using cached watchdog-6.0.0-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Downloading sse_starlette-3.0.3-py3-none-any.whl (11 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl (39 kB)
# Using cached cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, wrapt, watchdog, uvicorn, python-multipart, pyjwt, jmespath, httpx-sse, docstring-parser, starlette, sse-starlette, importlib-metadata, cryptography, botocore, s3transfer, pydantic-settings, opentelemetry-api, opentelemetry-semantic-conventions, mcp, boto3, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-threading, strands-agents
# Successfully installed boto3-1.40.66 botocore-1.40.66 cryptography-46.0.3 docstring-parser-0.17.0 httpx-sse-0.4.3 importlib-metadata-8.7.0 jmespath-1.0.1 mcp-1.20.0 opentelemetry-api-1.38.0 opentelemetry-instrumentation-0.59b0 opentelemetry-instrumentation-threading-0.59b0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pydantic-settings-2.11.0 pyjwt-2.10.1 python-multipart-0.0.20 s3transfer-0.14.0 sse-starlette-3.0.3 starlette-0.50.0 strands-agents-1.15.0 uvicorn-0.38.0 watchdog-6.0.0 wrapt-1.17.3 zipp-3.23.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Credentials for SAP Gen AI Hub
# Get the service key from your SAP BTP tenant with AI subscription.
#
# Add the following variables from the service key in a file called ".env" and put it in the same folder where you run the notebook:
# ```
# "AICORE_AUTH_URL": "https://* * * .authentication.sap.hana.ondemand.com/oauth/token",
# "AICORE_CLIENT_ID": " *** ",
# "AICORE_CLIENT_SECRET": " *** ",
# "AICORE_RESOURCE_GROUP": " *** ",
# "AICORE_BASE_URL": "https://api.ai.***.cfapps.sap.hana.ondemand.com/
# ```

# %% [markdown]
# ## Run the Strands Agents with LiteLLM and SAP LLMs

# %%
from strands.models.litellm import LiteLLMModel
from strands import Agent
from strands import tool
from dotenv import load_dotenv

# %% [markdown]
# Load your credentials as environment variables that Litellm can use automatically.

# %%
load_dotenv()

# %% [markdown]
# Define the agent tools.

# %%
@tool
def get_weather(city: str):
    city_normalized = city.lower().replace(" ", "")

    mock_weather_db = {
        "newyork": "The weather in New York is sunny with a temperature of 25°C.",
        "london": "It's cloudy in London with a temperature of 15°C.",
        "tokyo": "Tokyo is experiencing light rain and a temperature of 18°C.",
    }

    if city_normalized in mock_weather_db:
        return mock_weather_db[city_normalized]
    else:
        return f"The weather in {city} is sunny with a temperature of 20°C."

# %% [markdown]
# Create the agent with a LiteLLMModel object as a model.

# %%
agent = Agent(
    system_prompt="You are a helpful weather assistant. "
            "When the user send you asks a specific city, "
            "use the 'get_weather' tool to find the information about the weather. "
            "Aser with TV weather report in two sentences, include small jok",
    model=LiteLLMModel(model_id="sap/gpt-5"),
    tools=[get_weather],
)

# %% [markdown]
# Run agent with your prompt

# %%
response = agent("london")
print(response)
